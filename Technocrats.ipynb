# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
dataset = pd.read_csv("analytics.csv")

# %%
dataset.head(10)
# Out:
#    Unnamed: 0 Customer_placed_order_datetime  \
# 0           0                    14 20:27:45
# 1           1                    07 20:16:28
# 2           2                    13 19:35:09
# 3           3                    22 19:47:53
# 4           4                    03 19:01:52
# 5           5                    09 01:38:55
# 6           6                    18 01:28:46
# 7           7                    02 02:13:30
# 8           8                    07 00:50:25
# 9           9                    22 01:03:53
#
#   Placed_order_with_restaurant_datetime Driver_at_restaurant_datetime  \
# 0                           14 20:29:41                   14 20:39:32
# 1                           07 20:17:32                   07 20:36:00
# 2                           13 19:39:26                   13 20:28:16
# 3                           22 19:56:08                   22 20:01:20
# 4                           03 19:09:08                   03 19:36:20
# ...

# %%
dataset.describe()
# Out:
#          Unnamed: 0     Driver_ID  Restaurant_ID    Consumer_ID   Order_total  \
# count  18078.000000  18078.000000   18078.000000   18078.000000  18078.000000
# mean    9038.500000    222.448169     108.721263   32010.313475     51.261496
# std     5218.813419    105.219194      98.609766   42010.215766     50.599675
# min        0.000000      7.000000       2.000000       5.000000      0.000000
# 25%     4519.250000    141.000000      23.000000    4243.500000     26.660000
# 50%     9038.500000    227.000000      77.000000   10972.000000     38.630000
# 75%    13557.750000    314.000000     186.000000   56857.000000     57.885000
# max    18077.000000    438.000000     409.000000  200449.000000   1604.130000
#
#        Amount_of_discount  Amount_of_tip  Refunded_amount
# count        18078.000000   18078.000000     18078.000000
# mean             1.356706       3.492022         0.612091
# std              6.516667       3.700115         6.073104
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18078 entries, 0 to 18077
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             18078 non-null  int64
#  1   Customer_placed_order_datetime         18078 non-null  object
#  2   Placed_order_with_restaurant_datetime  18038 non-null  object
#  3   Driver_at_restaurant_datetime          13547 non-null  object
#  4   Delivered_to_consumer_datetime         18078 non-null  object
#  5   Driver_ID                              18078 non-null  int64
#  6   Restaurant_ID                          18078 non-null  int64
#  7   Consumer_ID                            18078 non-null  int64
#  8   Is_New                                 18078 non-null  bool
#  9   Delivery_Region                        18078 non-null  object
# ...

# %%
grouped_dataset = dataset.groupby('Delivery_Region')['Refunded_amount'].sum().reset_index()
plt.bar(grouped_dataset['Delivery_Region'], grouped_dataset['Refunded_amount'])
plt.xlabel('Delivery Region')
plt.ylabel('Refunded Amount')
plt.title('Analysis of Possiblity of Delivery Scams')
plt.show()

# %%
plt.hist(dataset['Order_total'], bins=20)
plt.xlabel('Order Total')
plt.ylabel('Frequency')
plt.title('Histogram of Total Amount of the Order')
plt.show()

# %%
plt.scatter(dataset['Order_total'], dataset['Refunded_amount'])
plt.xlabel('Order Total')
plt.ylabel('Refunded Amount')
plt.title('Order Total vs Refunded Amount')
plt.show()
